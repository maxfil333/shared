# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Logloss (функция потерь)

# %%
values = [-25, -10,-3, -2, -1, 0, 1, 2, 3, 10, 25]
y = []
for i in values:
    result = 1 / (1 + math.e**(-i))
    print(i, '<>', round(result, 5))
    y.append(result)

print()
sns.scatterplot(x=values, y=y)
# Out:
# -25 <> 0.0
# -10 <> 5e-05
# -3 <> 0.04743
# -2 <> 0.1192
# -1 <> 0.26894
# 0 <> 0.5
# 1 <> 0.73106
# 2 <> 0.8808
# 3 <> 0.95257
# 10 <> 0.99995
# 25 <> 1.0
# <Axes: >

# %%
values = [-1, -0.5, -0.1, 0, 0.1, 0.5, 1]
y = []
for i in values:
    result = 1 / (1 + math.e**(-i))
    print(i, '<>', round(result, 5))
    y.append(result)

print()
sns.scatterplot(x=values, y=y)
# Out:
# -1 <> 0.26894
# -0.5 <> 0.37754
# -0.1 <> 0.47502
# 0 <> 0.5
# 0.1 <> 0.52498
# 0.5 <> 0.62246
# 1 <> 0.73106
# <Axes: >

# %% [markdown]
# ## Энтропийный критерий

# %%
values = np.arange(0.1, 1, 0.1)
y = []
for i in values:
    result = -(i * np.log2(i)) - (1-i)*(np.log2(1-i))
    print(i, '<>', round(result, 5))
    y.append(result)
# Out:
# 0.1 <> 0.469
# 0.2 <> 0.72193
# 0.30000000000000004 <> 0.88129
# 0.4 <> 0.97095
# 0.5 <> 1.0
# 0.6 <> 0.97095
# 0.7000000000000001 <> 0.88129
# 0.8 <> 0.72193
# 0.9 <> 0.469

# %%
ax = sns.scatterplot(x=values, y=y)
ax.set(xlabel='∑ pi*log2(pi)', ylabel='Энтропия');

# %% [markdown]
# Максимальная энтропия (= 1) будет при вероятности быть классом i равной 50%

# %%
import numpy as np
np.random.seed(7)
train_data = np.random.normal(size=(100, 2))
train_labels = np.zeros(100)

# добавляем второй класс
train_data = np.r_[train_data, np.random.normal(size=(100, 2), loc=2)]
train_labels = np.r_[train_labels, np.ones(100)]

# %%
plt.rcParams['figure.figsize'] = (10,8)
plt.scatter(train_data[:, 0], train_data[:, 1], c=train_labels, s=100, cmap='autumn', edgecolors='black', linewidth=1.5);
plt.plot(range(-2,5), range(4,-3,-1));

# %%
def get_grid(data):
    x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
    y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
    return np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

get_grid(np.arange(10).reshape(2,5))
# Out:
# [array([[-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99],
#         [-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99],
#         [-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99],
#         ...,
#         [-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99],
#         [-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99],
#         [-1.  , -0.99, -0.98, ...,  5.97,  5.98,  5.99]]),
#  array([[0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ],
#         [0.01, 0.01, 0.01, ..., 0.01, 0.01, 0.01],
#         [0.02, 0.02, 0.02, ..., 0.02, 0.02, 0.02],
#         ...,
#         [6.97, 6.97, 6.97, ..., 6.97, 6.97, 6.97],
#         [6.98, 6.98, 6.98, ..., 6.98, 6.98, 6.98],
#         [6.99, 6.99, 6.99, ..., 6.99, 6.99, 6.99]])]

# %%
x = np.linspace(0.1, 100_000, 1000)

# %%
ax = plt.subplot()
ax.plot(x, np.log(x))
ax.set_xlabel('X', fontsize=12, loc="center", c="k")
ax.set_ylabel('Y', fontsize=12, loc="center", c="k")
plt.show()

# %%
np.log(0.01), np.log(1), np.log(np.e), np.log(2), np.log(7), np.log(10), np.log(100), np.log(1000)
# Out:
# (-4.605170185988091,
#  0.0,
#  1.0,
#  0.6931471805599453,
#  1.9459101490553132,
#  2.302585092994046,
#  4.605170185988092,
#  6.907755278982137)

# %%
np.e**7
# Out:
# 1096.6331584284583

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
x = np.linspace(1, 2, 5)
ax = plt.subplot()
ax.plot(x, np.log(x))
ax.set_xticks(x)
label = ax.set_xlabel('X ->', fontsize=16, loc="left", c="red")
ax.xaxis.set_label_coords(1.0, -0.025)
plt.show()
